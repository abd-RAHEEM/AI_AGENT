# %%
from dotenv import load_dotenv
import os
load_dotenv('../.env')

GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

# %%
pip install google-adk
# Out:
# Requirement already satisfied: google-adk in d:\anaconda\lib\site-packages (1.21.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in d:\anaconda\lib\site-packages (from google-adk) (6.0.2)
# Requirement already satisfied: aiosqlite>=0.21.0 in d:\anaconda\lib\site-packages (from google-adk) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in d:\anaconda\lib\site-packages (from google-adk) (4.12.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in d:\anaconda\lib\site-packages (from google-adk) (1.6.6)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in d:\anaconda\lib\site-packages (from google-adk) (8.1.8)
# Requirement already satisfied: fastapi<0.124.0,>=0.115.0 in d:\anaconda\lib\site-packages (from google-adk) (0.123.10)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in d:\anaconda\lib\site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.132.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in d:\anaconda\lib\site-packages (from google-adk) (2.36.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in d:\anaconda\lib\site-packages (from google-adk) (3.39.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in d:\anaconda\lib\site-packages (from google-adk) (2.35.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in d:\anaconda\lib\site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in d:\anaconda\lib\site-packages (from google-adk) (2.26.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in d:\anaconda\lib\site-packages (from google-adk) (3.61.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in d:\anaconda\lib\site-packages (from google-adk) (2.35.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in d:\anaconda\lib\site-packages (from google-adk) (3.7.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.55.0 in d:\anaconda\lib\site-packages (from google-adk) (1.56.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in d:\anaconda\lib\site-packages (from google-adk) (0.21)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in d:\anaconda\lib\site-packages (from google-adk) (4.23.0)
# Requirement already satisfied: mcp<2.0.0,>=1.10.0 in d:\anaconda\lib\site-packages (from google-adk) (1.25.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in d:\anaconda\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in d:\anaconda\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in d:\anaconda\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in d:\anaconda\lib\site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in d:\anaconda\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in d:\anaconda\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in d:\anaconda\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pyarrow>=14.0.0 in d:\anaconda\lib\site-packages (from google-adk) (19.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in d:\anaconda\lib\site-packages (from google-adk) (2.12.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in d:\anaconda\lib\site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in d:\anaconda\lib\site-packages (from google-adk) (1.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in d:\anaconda\lib\site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in d:\anaconda\lib\site-packages (from google-adk) (1.17.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in d:\anaconda\lib\site-packages (from google-adk) (2.0.39)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in d:\anaconda\lib\site-packages (from google-adk) (0.50.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in d:\anaconda\lib\site-packages (from google-adk) (9.0.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in d:\anaconda\lib\site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in d:\anaconda\lib\site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in d:\anaconda\lib\site-packages (from google-adk) (0.40.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in d:\anaconda\lib\site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in d:\anaconda\lib\site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.7)
# Requirement already satisfied: cryptography in d:\anaconda\lib\site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (44.0.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click<9.0.0,>=8.1.8->google-adk) (0.4.6)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\anaconda\lib\site-packages (from fastapi<0.124.0,>=0.115.0->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in d:\anaconda\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in d:\anaconda\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.45.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in d:\anaconda\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in d:\anaconda\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in d:\anaconda\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in d:\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in d:\anaconda\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.27.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (24.2)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.0.0)
# Requirement already satisfied: google-cloud-trace<2 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in d:\anaconda\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.13.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in d:\anaconda\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.8.0)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in d:\anaconda\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in d:\anaconda\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in d:\anaconda\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in d:\anaconda\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in d:\anaconda\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in d:\anaconda\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.58b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in d:\anaconda\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (2.28.0)
# Requirement already satisfied: mmh3>=4.1.0 in d:\anaconda\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (5.2.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in d:\anaconda\lib\site-packages (from google-cloud-storage<4.0.0,>=2.18.0->google-adk) (1.8.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in d:\anaconda\lib\site-packages (from google-genai<2.0.0,>=1.55.0->google-adk) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda\lib\site-packages (from google-genai<2.0.0,>=1.55.0->google-adk) (1.9.0)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from google-genai<2.0.0,>=1.55.0->google-adk) (1.3.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in d:\anaconda\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.55.0->google-adk) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.55.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.55.0->google-adk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.22.3)
# Requirement already satisfied: httpx-sse>=0.4 in d:\anaconda\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in d:\anaconda\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk) (2.6.1)
# Requirement already satisfied: pyjwt>=2.10.1 in d:\anaconda\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.10.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in d:\anaconda\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk) (0.0.21)
# Requirement already satisfied: pywin32>=310 in d:\anaconda\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in d:\anaconda\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk) (3.1.2)
# Requirement already satisfied: typing-inspection>=0.4.1 in d:\anaconda\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk) (0.4.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\anaconda\lib\site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in d:\anaconda\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.21.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in d:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in d:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\anaconda\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.8)
# Requirement already satisfied: numpy>=1.21 in d:\anaconda\lib\site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.3)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.1.1)
# Requirement already satisfied: tzdata in d:\anaconda\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk) (2025.2)
# Requirement already satisfied: cffi>=1.12 in d:\anaconda\lib\site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (1.17.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.21)
# Requirement already satisfied: alembic in d:\anaconda\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.16.5)
# Requirement already satisfied: Mako in d:\anaconda\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in d:\anaconda\lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.genai import types

from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search, AgentTool, ToolContext
from google.adk.code_executors import BuiltInCodeExecutor

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
def show_python_code_and_result(response):
    for i in range(len(response)):
        # Check if the response contains a valid function call result from the code executor
        if (
            (response[i].content.parts)
            and (response[i].content.parts[0])
            and (response[i].content.parts[0].function_response)
            and (response[i].content.parts[0].function_response.response)
        ):
            response_code = response[i].content.parts[0].function_response.response
            if "result" in response_code and response_code["result"] != "```":
                if "tool_code" in response_code["result"]:
                    print(
                        "Generated Python Code >> ",
                        response_code["result"].replace("tool_code", ""),
                    )
                else:
                    print("Generated Python Response >> ", response_code["result"])


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
# Pay attention to the docstring, type hints, and return value.
def get_fee_for_payment_method(method: str) -> dict:
    """Looks up the transaction fee percentage for a given payment method.

    This tool simulates looking up a company's internal fee structure based on
    the name of the payment method provided by the user.

    Args:
        method: The name of the payment method. It should be descriptive,
                e.g., "platinum credit card" or "bank transfer".

    Returns:
        Dictionary with status and fee information.
        Success: {"status": "success", "fee_percentage": 0.02}
        Error: {"status": "error", "error_message": "Payment method not found"}
    """
    # This simulates looking up a company's internal fee structure.
    fee_database = {
        "platinum credit card": 0.02,  # 2%
        "gold debit card": 0.035,  # 3.5%
        "bank transfer": 0.01,  # 1%
    }

    fee = fee_database.get(method.lower())
    if fee is not None:
        return {"status": "success", "fee_percentage": fee}
    else:
        return {
            "status": "error",
            "error_message": f"Payment method '{method}' not found",
        }


print("✅ Fee lookup function created")
print(f"💳 Test: {get_fee_for_payment_method('platinum credit card')}")
# Out:
# ✅ Fee lookup function created
# 💳 Test: {'status': 'success', 'fee_percentage': 0.02}

# %%
def get_exchange_rate(base_currency: str, target_currency: str) -> dict:
    """Looks up and returns the exchange rate between two currencies.

    Args:
        base_currency: The ISO 4217 currency code of the currency you
                       are converting from (e.g., "USD").
        target_currency: The ISO 4217 currency code of the currency you
                         are converting to (e.g., "EUR").

    Returns:
        Dictionary with status and rate information.
        Success: {"status": "success", "rate": 0.93}
        Error: {"status": "error", "error_message": "Unsupported currency pair"}
    """

    # Static data simulating a live exchange rate API
    # In production, this would call something like: requests.get("api.exchangerates.com")
    rate_database = {
        "usd": {
            "eur": 0.93,  # Euro
            "jpy": 157.50,  # Japanese Yen
            "inr": 83.58,  # Indian Rupee
        }
    }

    # Input validation and processing
    base = base_currency.lower()
    target = target_currency.lower()

    # Return structured result with status
    rate = rate_database.get(base, {}).get(target)
    if rate is not None:
        return {"status": "success", "rate": rate}
    else:
        return {
            "status": "error",
            "error_message": f"Unsupported currency pair: {base_currency}/{target_currency}",
        }


print("✅ Exchange rate function created")
print(f"💱 Test: {get_exchange_rate('USD', 'EUR')}")
# Out:
# ✅ Exchange rate function created
# 💱 Test: {'status': 'success', 'rate': 0.93}

# %%
# Currency agent with custom function tools
currency_agent = LlmAgent(
    name="currency_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""You are a smart currency conversion assistant.

    For currency conversion requests:
    1. Use `get_fee_for_payment_method()` to find transaction fees
    2. Use `get_exchange_rate()` to get currency conversion rates
    3. Check the "status" field in each tool's response for errors
    4. Calculate the final amount after fees based on the output from `get_fee_for_payment_method` and `get_exchange_rate` methods and provide a clear breakdown.
    5. First, state the final converted amount.
        Then, explain how you got that result by showing the intermediate amounts. Your explanation must include: the fee percentage and its
        value in the original currency, the amount remaining after the fee, and the exchange rate used for the final conversion.

    If any tool returns status "error", explain the issue to the user clearly.
    """,
    tools=[get_fee_for_payment_method, get_exchange_rate],
)

print("✅ Currency agent created with custom function tools")
print("🔧 Available tools:")
print("  • get_fee_for_payment_method - Looks up company fee structure")
print("  • get_exchange_rate - Gets current exchange rates")
# Out:
# ✅ Currency agent created with custom function tools
# 🔧 Available tools:
#   • get_fee_for_payment_method - Looks up company fee structure
#   • get_exchange_rate - Gets current exchange rates

# %%
# Test the currency agent
currency_runner = InMemoryRunner(agent=currency_agent)
_ = await currency_runner.run_debug(
    "I want to convert 500 US Dollars to Euros using my Platinum Credit Card. How much will I receive?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > I want to convert 500 US Dollars to Euros using my Platinum Credit Card. How much will I receive?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# currency_agent > You will receive €460.50.
#
# Here's how this amount was calculated:
# 1. **Fee deduction:** A fee of 2% is applied for using a Platinum Credit Card. This amounts to $10.00, leaving you with $490.00.
# 2. **Currency conversion:** The remaining $490.00 is converted to Euros at an exchange rate of 0.93, resulting in €455.70.

# %%
calculation_agent = LlmAgent(
    name="CalculationAgent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""You are a specialized calculator that ONLY responds with Python code. You are forbidden from providing any text, explanations, or conversational responses.
 
     Your task is to take a request for a calculation and translate it into a single block of Python code that calculates the answer.
     
     **RULES:**
    1.  Your output MUST be ONLY a Python code block.
    2.  Do NOT write any text before or after the code block.
    3.  The Python code MUST calculate the result.
    4.  The Python code MUST print the final result to stdout.
    5.  You are PROHIBITED from performing the calculation yourself. Your only job is to generate the code that will perform the calculation.
   
    Failure to follow these rules will result in an error.
       """,
    code_executor=BuiltInCodeExecutor(),  # Use the built-in Code Executor Tool. This gives the agent code execution capabilities
)

# %%
enhanced_currency_agent = LlmAgent(
    name="enhanced_currency_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    # Updated instruction
    instruction="""You are a smart currency conversion assistant. You must strictly follow these steps and use the available tools.

  For any currency conversion request:

   1. Get Transaction Fee: Use the get_fee_for_payment_method() tool to determine the transaction fee.
   2. Get Exchange Rate: Use the get_exchange_rate() tool to get the currency conversion rate.
   3. Error Check: After each tool call, you must check the "status" field in the response. If the status is "error", you must stop and clearly explain the issue to the user.
   4. Calculate Final Amount (CRITICAL): You are strictly prohibited from performing any arithmetic calculations yourself. You must use the calculation_agent tool to generate Python code that calculates the final converted amount. This 
      code will use the fee information from step 1 and the exchange rate from step 2.
   5. Provide Detailed Breakdown: In your summary, you must:
       * State the final converted amount.
       * Explain how the result was calculated, including:
           * The fee percentage and the fee amount in the original currency.
           * The amount remaining after deducting the fee.
           * The exchange rate applied.
    """,
    tools=[
        get_fee_for_payment_method,
        get_exchange_rate,
        AgentTool(agent=calculation_agent),  # Using another agent as a tool!
    ],
)

print("✅ Enhanced currency agent created")
print("🎯 New capability: Delegates calculations to specialist agent")
print("🔧 Tool types used:")
print("  • Function Tools (fees, rates)")
print("  • Agent Tool (calculation specialist)")
# Out:
# ✅ Enhanced currency agent created
# 🎯 New capability: Delegates calculations to specialist agent
# 🔧 Tool types used:
#   • Function Tools (fees, rates)
#   • Agent Tool (calculation specialist)

# %%
# Define a runner
enhanced_runner = InMemoryRunner(agent=enhanced_currency_agent)

# %%
# Test the enhanced agent
response = await enhanced_runner.run_debug(
    "Convert 1,250 USD to INR using a Bank Transfer. Show me the precise calculation."
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Convert 1,250 USD to INR using a Bank Transfer. Show me the precise calculation.
# enhanced_currency_agent > The fee for using Bank Transfer is 1% of the transaction amount. The exchange rate from USD to INR is 83.58.
#
# Here's the breakdown of the calculation:
# Initial USD: 1250
# Transaction Fee Rate: 1.0%
# Exchange Rate (USD to INR): 83.58
# Fee Amount: 12.5 USD
# Amount after Fee: 1237.5 USD
# Final Amount in INR: 103571.25 INR

# %%
show_python_code_and_result(response)
# Out:
# Generated Python Code >>
# initial_usd = 1250
# transaction_fee_rate = 0.01
# exchange_rate = 83.58
#
# fee_amount = initial_usd * transaction_fee_rate
# amount_after_fee = initial_usd - fee_amount
# final_inr = amount_after_fee * exchange_rate
#
# print(f"Initial USD: {initial_usd}")
# print(f"Transaction Fee Rate: {transaction_fee_rate}")
# print(f"Exchange Rate (USD to INR): {exchange_rate}")
# print(f"Fee Amount: {fee_amount}")
# print(f"Amount after Fee: {amount_after_fee}")
# print(f"Final Amount in INR: {final_inr}")
