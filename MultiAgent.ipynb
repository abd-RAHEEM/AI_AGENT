# %%
pip install google-adk
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from the .env file in the parent directory
load_dotenv('../.env')

# Access the API key
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > The integration of quantum computing and AI, known as Quantum AI, is rapidly advancing and is set to revolutionize many fields. Key developments include:
#
# *   **Enhanced Computational Power for AI:** Quantum computers offer exponential increases in processing power, enabling AI to handle vast datasets and solve complex problems much faster. This impact is expected to be significant by 2030.
# *   **Accelerated AI Training and Problem-Solving:** Quantum computing drastically reduces the time needed to train AI models and allows for the solution of complex mathematical problems that are currently intractable for classical computers. This has implications for drug discovery, materials science, and logistics.
# *   **Hardware Progress and Hybrid Approaches:** Companies are developing more advanced quantum processors, and significant breakthroughs are being made in quantum error correction. Hybrid approaches, combining quantum and classical computing, are crucial for near-term advancements.
# *   **Emerging Applications and Market Growth:** Early applications are already showing promise, such as in protein structure prediction. The global quantum market is projected for substantial growth, indicating strong investment and interest in the transformative potential of Quantum AI.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Hello! OutlineAgent here, ready to help you craft a compelling blog post. Here's an outline on the benefits of multi-agent systems for software developers:
#
# ---
#
# ## Blog Post Outline: Multi-Agent Systems for Software Developers
#
# **1. Catchy Headline:**
#
# *   **Option 1:** Unleash Your Code's Potential: How Multi-Agent Systems Revolutionize Software Development
# *   **Option 2:** Beyond Monoliths: Why Every Developer Needs to Understand Multi-Agent Systems
# *   **Option 3:** The Future is Collaborative: Supercharging Your Development with Multi-Agent Systems
#
# **2. Introduction Hook:**
#
# *   Imagine a software development environment where tasks are intelligently distributed, modules proactively communicate, and the system as a whole learns and adapts. This isn't science fiction; it's the reality being shaped by **multi-agent systems (MAS)**. For software developers, embracing MAS isn't just about adopting a new buzzword – it's about unlocking a new paradigm of building more robust, scalable, and intelligent applications. This post will explore the tangible benefits MAS offer to developers, transforming how we design, build, and maintain software.
#
# **3. Main Sections:**
#
# *   **Section 1: Enhanced Modularity and Decoupling**
#     *   **Agent as Independent Unit:** Each agent can represent a specific function, service, or even a subsystem, allowing for clear separation of concerns.
#     *   **Reduced Interdependencies:** Agents interact through well-defined interfaces, minimizing complex, tightly coupled dependencies that plague traditional architectures.
#     *   **Easier Maintenance and Updates:** Individual agents can be updated, debugged, or even replaced without significantly impacting the rest of the system.
#
# *   **Section 2: Improved Scalability and Resilience**
#     *   **Distributed Problem Solving:** MAS can naturally distribute computational load across multiple agents, allowing systems to scale horizontally by adding more agents.
#     *   **Fault Tolerance:** If one agent fails, others can often take over its responsibilities or work around the issue, leading to more resilient systems.
#     *   **Dynamic Reconfiguration:** Agents can be added, removed, or reallocated on the fly to adapt to changing demands and resource availability.
#
# *   **Section 3: Intelligent Behavior and Autonomy**
#     *   **Proactive Task Execution:** Agents can be designed to act autonomously, anticipating needs and initiating actions without constant human oversight.
#     *   **Learning and Adaptation:** Agents can learn from their environment and interactions, enabling systems to evolve and improve their performance over time.
#     *   **Complex System Modeling:** MAS provides a powerful framework for modeling and simulating complex real-world systems, from traffic management to financial markets.
#
# *   **Section 4 (Optional): Streamlined Development Workflow**
#     *   **Parallel Development:** Different teams can work on individual agents concurrently, accelerating the development cycle.
#     *   **Reusable Components:** Well-defined agents can be designed as reusable components for future projects, saving development time and effort.
#     *   **Simpler Testing:** Individual agents can be tested in isolation, making unit and integration testing more manageable.
#
# **4. Concluding Thought:**
#
# *   Multi-agent systems offer a fundamental shift in how we approach software architecture and development. By embracing the principles of distributed intelligence, modularity, and autonomy, developers can build systems that are not only more powerful and efficient but also more adaptable to the ever-changing digital landscape. As you look to build the next generation of intelligent and scalable software, consider the profound advantages that a multi-agent approach can bring to your development toolkit.
#
# ---
#
# Let me know if you'd like any adjustments or further elaboration on any of these points!
# WriterAgent > ## Unleash Your Code's Potential: How Multi-Agent Systems Revolutionize Software Development
#
# Imagine a software development environment where tasks are intelligently distributed, modules proactively communicate, and the system as a whole learns and adapts. This isn't science fiction; it's the reality being shaped by **multi-agent systems (MAS)**. For software developers, embracing MAS isn't just about adopting a new buzzword – it's about unlocking a new paradigm of building more robust, scalable, and intelligent applications.
#
# At its core, MAS treats software components as independent "agents." This promotes **enhanced modularity and decoupling**. Each agent can encapsulate a specific function, minimizing complex interdependencies. The benefit for developers? Easier maintenance and updates. If one agent needs tweaking, the rest of the system remains largely unaffected, a stark contrast to monolithic architectures.
#
# MAS also dramatically improves **scalability and resilience**. By distributing computational load across multiple agents, systems can scale horizontally simply by adding more agents. If one agent falters, others can often step in, creating fault-tolerant systems that are more robust against failures. This dynamic nature allows for on-the-fly reconfiguration, adapting to shifting demands.
#
# Furthermore, agents can exhibit **intelligent behavior and autonomy**. They can be programmed to anticipate needs and act proactively, even learning and adapting over time. This empowers developers to build systems that not only perform complex tasks but also evolve and improve. As you look to build the next generation of intelligent software, consider the profound advantages that a multi-agent approach can bring to your development toolkit.
# EditorAgent > ## Unleash Your Code's Potential: How Multi-Agent Systems Revolutionize Software Development
#
# Imagine a software development environment where tasks are intelligently distributed, modules proactively communicate, and the system as a whole learns and adapts. This isn't science fiction; it's the reality being shaped by **multi-agent systems (MAS)**. For software developers, embracing MAS isn't just about adopting a new buzzword – it's about unlocking a new paradigm for building more robust, scalable, and intelligent applications. This post will explore the tangible benefits MAS offer to developers, transforming how we design, build, and maintain software.
#
# ### Enhanced Modularity and Decoupling: The Power of Independent Units
#
# At its core, MAS treats software components as independent "agents." Each agent can encapsulate a specific function, service, or even a subsystem, allowing for a clear separation of concerns. This design promotes **enhanced modularity and decoupling**. Instead of wrestling with complex, tightly coupled dependencies that plague traditional architectures, agents interact through well-defined interfaces. The direct benefit for developers is significantly easier maintenance and updates. If one agent needs tweaking, debugging, or even replacement, the rest of the system remains largely unaffected, a stark contrast to the ripple effects often seen in monolithic architectures.
#
# ### Improved Scalability and Resilience: Building Systems That Grow and Endure
#
# MAS dramatically improves **scalability and resilience**. By distributing computational load across multiple agents, systems can scale horizontally simply by adding more agents. This inherent flexibility allows applications to effortlessly adapt to increasing demands. Furthermore, if one agent falters, others can often step in to take over its responsibilities or work around the issue, creating inherently fault-tolerant systems that are more robust against failures. This dynamic nature also enables on-the-fly reconfiguration, allowing systems to adapt to shifting demands and resource availability without downtime.
#
# ### Intelligent Behavior and Autonomy: Empowering Proactive Systems
#
# Beyond structure, agents can exhibit **intelligent behavior and autonomy**. They can be programmed to anticipate needs, initiate actions proactively, and even learn from their environment and interactions. This capability empowers developers to build systems that not only perform complex tasks but also evolve and improve their performance over time without constant human oversight. MAS provides a powerful framework for modeling and simulating complex real-world systems, opening doors to applications that can truly adapt and optimize themselves.
#
# ### The Future is Collaborative and Intelligent
#
# Multi-agent systems offer a fundamental shift in how we approach software architecture and development. By embracing the principles of distributed intelligence, modularity, and autonomy, developers can build systems that are not only more powerful and efficient but also more adaptable to the ever-changing digital landscape. As you look to build the next generation of intelligent and scalable software, consider the profound advantages that a multi-agent approach can bring to your development toolkit.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > Here's a briefing on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:**
# *   **Gene Therapy Advances:** CRISPR technology is enabling precise DNA editing for genetic diseases like sickle cell anemia. Its application is expanding, with ongoing trials for various inherited disorders. Timeline: Already in use, with broader applications expected in the next 5-10 years.
# *   **Regenerative Medicine:** Development of implantable patches to repair heart tissue and lab-grown organoids show promise for treating organ failure. Timeline: Early stages, with significant clinical impact anticipated within 10-15 years.
# *   **AI in Diagnostics:** AI is enhancing medical imaging analysis for earlier disease detection, particularly in oncology. Timeline: Currently being implemented, with increasing sophistication expected in the next 5 years.
#
# **Technology:**
# *   **Agentic AI:** AI is evolving from assistants to autonomous agents capable of executing complex workflows. Timeline: Rapid development, with widespread enterprise adoption expected within 3-5 years.
# *   **Neural Interfaces (BCIs):** Brain-computer interfaces are moving from research to practical applications in controlling devices and restoring mobility, enhanced by AI. Timeline: Emerging applications, with broader consumer and medical use in 5-10 years.
# *   **Quantum Computing:** Progress is being made in error correction, making scalable quantum computers more feasible. Timeline: Practical applications are still 5-10+ years away, but progress is accelerating.
#
# **Finance:**
# *   **Embedded Finance:** Financial services are increasingly integrated into non-financial platforms, revolutionizing commerce. Timeline: Already prevalent, with continued expansion expected in the next 3-5 years.
# *   **Tokenized Real-World Assets (RWAs):** Blockchain is enabling fractional ownership of assets like real estate and art, democratizing investment. Timeline: Growing adoption, with significant market impact expected within 5-7 years.
# *   **AI-Powered Financial Advice:** AI chatbots are providing personalized financial planning and investment recommendations. Timeline: Increasingly common, with advanced capabilities expected in the next 2-4 years.
# TechResearcher > **Key AI/ML Trends:**
#
# 1.  **Generative AI Advancements:** Generative AI continues to dominate, expanding beyond text to create complex multimedia content like graphics, video, and music. Major players like Google (Imagen, Muse) and OpenAI (GPT models) are pushing these boundaries. This trend fuels creativity and offers new practical applications across industries.
#
# 2.  **Shift to Smaller, Efficient Models:** There's a growing trend towards Small Language Models (SLMs) as a more efficient alternative to Large Language Models (LLMs), particularly for specific tasks and on edge devices. This allows for better performance with reduced computational resources.
#
# 3.  **Multimodal AI Integration:** AI systems are increasingly capable of processing and integrating multiple data types simultaneously—text, images, audio, and video. This leads to more human-like interactions and richer, more robust AI experiences. Companies like Google are developing these capabilities.
#
# **Companies Involved:**
# Key companies driving these trends include Google, OpenAI, Microsoft, NVIDIA, Amazon, and IBM, alongside specialized AI firms like Databricks and Anthropic.
#
# **Potential Impact:**
# These advancements promise to revolutionize industries by enhancing automation, personalizing services, improving decision-making, and creating new forms of content. However, they also bring challenges in AI safety, security, and ethical deployment.
# FinanceResearcher > Here's your executive briefing for January 5, 2026:
#
# **Technology:** The tech landscape in 2026 is dominated by AI's shift from hype to practical application. Expect AI integration across devices, from smartphones and laptops to home appliances and robots. Foldable phones and advanced display technologies will continue to emerge, alongside a focus on AI-optimized hardware and specialized AI chips. The startup birth rate is also soaring, driven by AI coding tools, potentially reshaping the industry.
#
# **Health:** Health trends in 2026 emphasize personalized, preventative care and holistic well-being. Continuous hormone monitors and AI-powered wearables will offer deeper health insights. "Food as Medicine," functional nutrition, and longevity science are gaining prominence, with a focus on gut health and metabolic efficiency. Digital detox and analog wellness practices are also on the rise as a response to increased connectivity.
#
# **Finance:** The financial sector in 2026 is driven by "Agentic AI" and a "Workflow Revolution," redefining how work is done. Increased collaboration between CIOs and CFOs will steer AI and fintech decisions. Digital assets, including tokenization and stablecoins, will become central to financial services. Institutions will focus on hyperscaler neutrality for flexibility and navigate increasing geopolitical and regulatory complexities.
# AggregatorAgent > **Executive Summary: Tech, Health, and Finance Briefing**
#
# The convergence of AI, particularly generative and multimodal capabilities, is profoundly reshaping all three sectors. In **Technology**, AI is moving beyond assistants to become autonomous agents driving complex workflows, with rapid enterprise adoption expected within 3-5 years. This is complemented by advancements in smaller, efficient models and specialized AI hardware, while neural interfaces and quantum computing show longer-term promise.
#
# **Health** is experiencing a personalized and preventative revolution, largely powered by AI diagnostics for earlier disease detection. Gene therapy and regenerative medicine offer groundbreaking treatments for genetic and organ failure, with significant clinical impact anticipated in the coming years. AI-powered wearables and continuous monitoring are providing deeper health insights, aligning with trends in functional nutrition and longevity science.
#
# In **Finance**, "Agentic AI" and a "Workflow Revolution" are redefining operations, with AI-driven financial advice and embedded finance becoming increasingly prevalent. Digital assets, including tokenization of real-world assets, are democratizing investment and are set to become central to financial services. Collaboration between CIOs and CFOs will be critical in navigating these AI and fintech advancements amid evolving regulatory landscapes.
#
# **Key Takeaways:**
# *   **AI as the Primary Driver:** AI is the central theme, powering innovations across technology, enabling breakthroughs in health diagnostics and treatments, and revolutionizing financial services and workflows.
# *   **Personalization and Efficiency:** Trends emphasize personalized experiences in health and finance, alongside a push for more efficient AI models and optimized hardware.
# *   **Long-Term vs. Near-Term Impact:** While immediate impacts are seen in agentic AI, embedded finance, and AI diagnostics, gene therapy, regenerative medicine, and quantum computing represent significant, albeit longer-term, disruptive potentials.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias, a man weathered by sea salt and solitude, polished the great lens of the lighthouse. The foghorn’s mournful cry was his only companion on nights like these. As he descended the spiral stairs, a glint of light caught his eye. Tucked beneath a loose floorboard, a rolled parchment pulsed with an ethereal, aquamarine glow. Unfurling it, Elias found no familiar coastlines, no charted waters. Instead, a swirling constellation of luminous symbols depicted a place unseen, a phantom island marked by a single, blazing star. His heart, usually as steady as the lighthouse beam, began to pound. The sea, his lifelong adversary and friend, held a new, radiant secret.
# CriticAgent > The story is promising, with a strong sense of atmosphere and a compelling inciting incident. Here are a few suggestions for improvement:
#
# 1.  **Deepen Elias's Characterization:** While the description of Elias as "weathered by sea salt and solitude" is effective, explore *why* he is solitary. Does he embrace it, or is he resigned to it? A brief internal thought or memory could reveal more about his past and his feelings about his current life, making his reaction to the map more impactful. For example, a thought like, "He hadn't felt this surge of anticipation since his youth, before the sea claimed all his dreams," could add a layer of depth.
#
# 2.  **Enhance the Mystery of the Map:** The description of the map is intriguing, but consider adding a sensory detail beyond its glow. Does it feel ancient? Is there a faint scent associated with it, like ozone or a specific sea herb? Is there a subtle texture to the symbols? These additions can make the map feel more tangible and increase its mystique. Perhaps the parchment itself feels unnaturally smooth or cool to the touch.
#
# 3.  **Hint at the Stakes or Next Steps:** The story ends with Elias's heart pounding and a realization of a "radiant secret." This is a good hook, but it leaves the reader wondering what Elias will do next. Briefly allude to a potential course of action or the immediate impact of this discovery. Will he try to decipher the map? Will it change his routine? Even a single sentence suggesting his newfound purpose or a hint of apprehension about this secret could strengthen the conclusion and leave a stronger impression. For instance, "For the first time in decades, the solitary life of the lighthouse keeper felt like a prelude, not an ending."
# RefinerAgent > Elias, a man weathered by sea salt and solitude, polished the great lens of the lighthouse. The foghorn’s mournful cry was his only companion on nights like these, a sound he’d grown accustomed to, perhaps even found a strange comfort in, after the sea had claimed his dreams of a life beyond this lonely tower decades ago. As he descended the spiral stairs, a glint of light caught his eye. Tucked beneath a loose floorboard, a rolled parchment pulsed with an ethereal, aquamarine glow. Unfurling it, Elias found no familiar coastlines, no charted waters. The parchment itself felt unnaturally smooth and cool to the touch, ancient and strangely alive. Instead of ink, a swirling constellation of luminous symbols depicted a place unseen, a phantom island marked by a single, blazing star. A faint scent, like ozone after a storm, clung to it. His heart, usually as steady as the lighthouse beam, began to pound. He hadn’t felt this surge of anticipation since his youth. The sea, his lifelong adversary and friend, held a new, radiant secret. For the first time in decades, the solitary life of the lighthouse keeper felt like a prelude, not an ending. He knew, with a certainty that settled deep in his bones, that he had to decipher this map.
# CriticAgent > The story is well-written and complete.
#
# APPROVED
